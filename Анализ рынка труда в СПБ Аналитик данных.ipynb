# %% [markdown]
# <a href="https://colab.research.google.com/github/alexeiveselov92/other_projects/blob/master/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D1%80%D1%8B%D0%BD%D0%BA%D0%B0%20%D1%82%D1%80%D1%83%D0%B4%D0%B0%20%D0%B2%20%D0%A1%D0%9F%D0%91%20%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Описание работы
# Необходимо было провести анализ рынка труда в Санкт-Петербурге по вакансиям на hh.ru по ключевым запросам:
# 1. Data Scientist
# 2. Аналитик данных
# 3. Аналитик
#
# Целью работы является выявление средней заработной платы, а также наиболее важных ключевых навыков по вакансиям.
#
# Для проведения анализа была сделана выгрузка всех вакансий с площадки hh.ru по ключевым словам через Google Sheets с помощью XPath запросов. Далее в Google Sheets были удалены нерелевантные вакансии и значения зарплат были переведены в русские рубли.

# %% [markdown]
# # Спецификация
# * **`keywords`** - ключевые слова при поиске вакансий на hh.ru
# * **`company`** - название компании работодателя
# * **`position`** - название вакансии
# * **`link`** - ссылка на вакансию
# * **`salary`** - заработная плата
# * **`key_skills`** - ключевые навыки, необходимые под вакансию

# %% [markdown]
# # Загрузка библиотек

# %%
import pandas as pd
import math as mth
from scipy import stats as st
import random
import numpy as np

#визуализация
import matplotlib.pyplot as plt
from plotly import graph_objects as go
import plotly.express as px
import seaborn as sns; sns.set()

#загрузка файлов локально и с диска
from google.colab import files
from google.colab import drive
# drive.mount('/content/drive')
#чтобы помещалось все горизонтально
pd.options.display.expand_frame_repr = False

import warnings
warnings.filterwarnings('ignore')

#загрузка файла локально
#uploaded = files.upload()

#загрузка с гугл диска (надо подключиться к google диску либо через drive.mount('/content/drive') либо нажав кнопку 'Mount Drive')
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Загрузка датасета
# Датасет заранее был отчищен от нерелевантных вакансий и дубликатов при выгрузке.
#
# При выгрузке вакансий по ключевым словам по разным запросам выгружались одни и те же вакансии.
#
# Поэтому при выгрузке одних и тех же вакансий по одним и тем же запросам присваивались ключевые слова менее частотного запроса.
#
# Т.е. приоритет давался сначала "Data Scientist", затем "Аналитик данных" и только потом уже "Аналитик".

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/vacancies_spb_it.csv')
df.head(5)
# Out:
#           keywords       company                  position                                               link   salary                                         key_skills
# 0  аналитик данных        Fmedia  Аналитик (отдел закупок)  https://spb.hh.ru/analytics_source/vacancy/367...      NaN  MS Outlook, Internet Marketing, Закупка товаро...
# 1  аналитик данных         Авито    Аналитик отдела продаж                 https://spb.hh.ru/vacancy/35000627      NaN  SQL, MS SQL, Бизнес-анализ, Экономический анал...
# 2  аналитик данных     ООО ЭДГОУ                  Аналитик                 https://spb.hh.ru/vacancy/36812321  80000.0  Python, SQL, Data Mining, Английский язык, Ана...
# 3  аналитик данных  Бронка Групп         Товарный аналитик                 https://spb.hh.ru/vacancy/36069746  60000.0  Прогнозирование, Анализ финансовых показателей...
# 4  аналитик данных    First_Line       Финансовый аналитик                 https://spb.hh.ru/vacancy/36157991  40000.0  Финансовый анализ, Управленческий учет, Анализ...

# %% [markdown]
# # Посмотрим средние зарплаты по вакансиям и общую статистику

# %%
print('Из {} вакансий величина ЗП указана в {} случаях ({:.2%})'.format(len(df), df['salary'].count(), df['salary'].count()/len(df)))
print('Из {} вакансий ключевые навыки указаны в {} случаях ({:.2%})'.format(len(df), df['key_skills'].count(), df['key_skills'].count()/len(df)))
print('Всего компаний в выгрузке: {}'.format(len(df['company'].unique())))
grouped_by_keywords = df.groupby('keywords').agg({'company':'nunique', 'position':'count', 'salary':['count', 'mean', 'median'], 'key_skills':'count'})
grouped_by_keywords.columns = ['companies', 'positions', 'vacancies_with_salary', 'mean_salary', 'median_salary', 'vacancies_with_key_skills']
grouped_by_keywords
# Out:
# Из 679 вакансий величина ЗП указана в 122 случаях (17.97%)
# Из 679 вакансий ключевые навыки указаны в 244 случаях (35.94%)
# Всего компаний в выгрузке: 364
#                  companies  positions  vacancies_with_salary    mean_salary  median_salary  vacancies_with_key_skills
# keywords
# Data Scientist          29         37                     12  117916.666667       100000.0                         16
# аналитик               210        327                     53   84792.452830        70000.0                        112
# аналитик данных        208        315                     57   78964.912281        70000.0                        116

# %% [markdown]
# > * Всего вакансий: 679
# * Всего компаний: 364
# * Заработную плату указали только в 18% случаев.
# * Ключевые навыки указали только в 35% случаев.
# * Средняя ЗП у Data Scientist: 100000 руб.
# * Средняя ЗП у аналитика данных: 70000 руб.
# * Средняя ЗП у аналитика: 70000 руб.

# %% [markdown]
# # ТОП-15 ключевых требуемых навыков в зависимости от вакансии

# %%
df[['key_skills']] = df[['key_skills']].fillna('*')
df['skills_list'] = df['key_skills'].apply(lambda x: x.split(', '))
df

skills_list = []
skills_analyst = []
skills_data_analyst = []
skills_data_scientist = []

lists = {
    'аналитик':skills_analyst,
    'аналитик данных':skills_data_analyst,
    'Data Scientist':skills_data_scientist
}


for keyword in lists:
  for skills in df.query('keywords==@keyword')['skills_list']:
    for skill in skills:
      if skill!='*':
        lists[keyword].append(skill)

skills_list = skills_analyst + skills_data_analyst + skills_data_scientist
  

skills_analyst_df = pd.DataFrame({'skill':skills_analyst})
skills_data_analyst_df = pd.DataFrame({'skill':skills_data_analyst})
skills_data_scientist_df = pd.DataFrame({'skill':skills_data_scientist})
skills = pd.DataFrame({'skill':skills_list})

skills_analyst_df = pd.DataFrame(skills_analyst_df['skill'].value_counts()).reset_index()
skills_data_analyst_df = pd.DataFrame(skills_data_analyst_df['skill'].value_counts()).reset_index()
skills_data_scientist_df = pd.DataFrame(skills_data_scientist_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_analyst_df.columns = ['skill', 'vacancies']
skills_data_analyst_df.columns = ['skill', 'vacancies']
skills_data_scientist_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_analyst_df['percent_of_vacancies'] = skills_analyst_df['vacancies'] / len(df.query('key_skills !="*" and keywords=="аналитик"'))
skills_data_analyst_df['percent_of_vacancies'] = skills_data_analyst_df['vacancies'] / len(df.query('key_skills !="*" and keywords=="аналитик данных"'))
skills_data_scientist_df['percent_of_vacancies'] = skills_data_scientist_df['vacancies'] / len(df.query('key_skills !="*" and keywords=="Data Scientist"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('key_skills !="*"'))

lists_for_plots = {
    'аналитик':skills_analyst_df,
    'аналитик данных':skills_data_analyst_df,
    'Data Scientist':skills_data_scientist_df, 
    'аналитик / аналитик данных / Data Scientist':skills
}

for keyword in lists_for_plots:
  fig = px.bar(lists_for_plots[keyword].head(15), 
              x='skill', y='vacancies', width = 1300, height = 650, color='skill', 
              text='vacancies')
  fig.update_xaxes(tickangle=30)
  fig.update_layout(
      title='ТОП-15 ключевых навыков в профессии {} в СПБ'.format(keyword),
      xaxis_title="Ключевой навык",
      yaxis_title="Вакансий с навыком")
  fig.update_traces(textposition='outside')
  for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
      trace.name = trace.name.split('=')[1] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff3dcaa5-a039-4c76-accd-17690ffc49a6" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff3dcaa5-a039-4c76-accd-17690ffc49a6")) {
#                     Plotly.newPlot(
#                         'ff3dcaa5-a039-4c76-accd-17690ffc49a6',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "marker": {"color": "#636efa"}, "name": "\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a (22.32% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "orientation": "v", "showlegend": true, "text": [25.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a"], "xaxis": "x", "y": [25], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437", "marker": {"color": "#EF553B"}, "name": "\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437 (19.64% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437", "orientation": "v", "showlegend": true, "text": [22.0], "textposition": "outside", "type": "bar", "x": ["\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437"], "xaxis": "x", "y": [22], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439", "marker": {"color": "#00cc96"}, "name": "\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439 (17.86% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439", "orientation": "v", "showlegend": true, "text": [20.0], "textposition": "outside", "type": "bar", "x": ["\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439"], "xaxis": "x", "y": [20], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0423\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u0435 \u043f\u0440\u043e\u0435\u043a\u0442\u0430\u043c\u0438", "marker": {"color": "#ab63fa"}, "name": "\u0423\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u0435 \u043f\u0440\u043e\u0435\u043a\u0442\u0430\u043c\u0438 (15.18% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0423\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u0435 \u043f\u0440\u043e\u0435\u043a\u0442\u0430\u043c\u0438", "orientation": "v", "showlegend": true, "text": [17.0], "textposition": "outside", "type": "bar", "x": ["\u0423\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u0435 \u043f\u0440\u043e\u0435\u043a\u0442\u0430\u043c\u0438"], "xaxis": "x", "y": [17], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435", "marker": {"color": "#FFA15A"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (12.50% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d7593a1a-c4ef-4bed-bad8-391bf846df53" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d7593a1a-c4ef-4bed-bad8-391bf846df53")) {
#                     Plotly.newPlot(
#                         'd7593a1a-c4ef-4bed-bad8-391bf846df53',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=SQL", "marker": {"color": "#636efa"}, "name": "SQL (40.52% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=SQL", "orientation": "v", "showlegend": true, "text": [47.0], "textposition": "outside", "type": "bar", "x": ["SQL"], "xaxis": "x", "y": [47], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Python", "marker": {"color": "#EF553B"}, "name": "Python (22.41% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Python", "orientation": "v", "showlegend": true, "text": [26.0], "textposition": "outside", "type": "bar", "x": ["Python"], "xaxis": "x", "y": [26], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "marker": {"color": "#00cc96"}, "name": "\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a (18.97% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "orientation": "v", "showlegend": true, "text": [22.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a"], "xaxis": "x", "y": [22], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u044f", "marker": {"color": "#ab63fa"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u044f (16.38% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u044f", "orientation": "v", "showlegend": true, "text": [19.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u044f"], "xaxis": "x", "y": [19], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=MS PowerPoint", "marker": {"color": "#FFA15A"}, "name": "MS PowerPoint (13.79% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=MS PowerPoint", "orientation": "v", "showlegend": true, "text": [16.0], "textposition": "outside", "type": "bar", "x": ["MS PowerPoint"], "xaxis": "x", "y": [16], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435", "marker": {"color": "#19d3f3"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (12.93% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435", "orientation": "v", "showlegend": true, "text": [15.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="96e09d38-1342-4831-b180-1728a1f3da28" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96e09d38-1342-4831-b180-1728a1f3da28")) {
#                     Plotly.newPlot(
#                         '96e09d38-1342-4831-b180-1728a1f3da28',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Python", "marker": {"color": "#636efa"}, "name": "Python (56.25% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Python", "orientation": "v", "showlegend": true, "text": [9.0], "textposition": "outside", "type": "bar", "x": ["Python"], "xaxis": "x", "y": [9], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Data Mining", "marker": {"color": "#EF553B"}, "name": "Data Mining (37.50% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Data Mining", "orientation": "v", "showlegend": true, "text": [6.0], "textposition": "outside", "type": "bar", "x": ["Data Mining"], "xaxis": "x", "y": [6], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Data Analysis", "marker": {"color": "#00cc96"}, "name": "Data Analysis (37.50% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Data Analysis", "orientation": "v", "showlegend": true, "text": [6.0], "textposition": "outside", "type": "bar", "x": ["Data Analysis"], "xaxis": "x", "y": [6], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B1 \u2014 \u0421\u0440\u0435\u0434\u043d\u0438\u0439", "marker": {"color": "#ab63fa"}, "name": "\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B1 \u2014 \u0421\u0440\u0435\u0434\u043d\u0438\u0439 (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B1 \u2014 \u0421\u0440\u0435\u0434\u043d\u0438\u0439", "orientation": "v", "showlegend": true, "text": [4.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B1 \u2014 \u0421\u0440\u0435\u0434\u043d\u0438\u0439"], "xaxis": "x", "y": [4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=SQL", "marker": {"color": "#FFA15A"}, "name": "SQL (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=SQL", "orientation": "v", "showlegend": true, "text": [4.0], "textposition": "outside", "type": "bar", "x": ["SQL"], "xaxis": "x", "y": [4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Big Data", "marker": {"color": "#19d3f3"}, "name": "Big Data (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Big Data", "orientation": "v", "showlegend": true, "text": [4.0], "textposition": "outside", "type": "bar", "x": ["Big Data"], "xaxis": "x", "y": [4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u041c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0430\u043d\u0430\u043b\u0438\u0437", "marker": {"color": "#FF6692"}, "name": "\u041c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0430\u043d\u0430\u043b\u0438\u0437 (18.75% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u041c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0430\u043d\u0430\u043b\u0438\u0437", "orientation": "v", "showlegend": true, "text": [3.0], "textposition": "outside", "type": "bar", "x": ["\u041c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0430\u043d\u0430\u043b\u0438\u0437"], "xaxis":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9bcf6123-e06c-4b6c-ac88-967d30689d21" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9bcf6123-e06c-4b6c-ac88-967d30689d21")) {
#                     Plotly.newPlot(
#                         '9bcf6123-e06c-4b6c-ac88-967d30689d21',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=SQL", "marker": {"color": "#636efa"}, "name": "SQL (26.23% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=SQL", "orientation": "v", "showlegend": true, "text": [64.0], "textposition": "outside", "type": "bar", "x": ["SQL"], "xaxis": "x", "y": [64], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "marker": {"color": "#EF553B"}, "name": "\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a (20.49% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a", "orientation": "v", "showlegend": true, "text": [50.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a"], "xaxis": "x", "y": [50], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=Python", "marker": {"color": "#00cc96"}, "name": "Python (17.62% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Python", "orientation": "v", "showlegend": true, "text": [43.0], "textposition": "outside", "type": "bar", "x": ["Python"], "xaxis": "x", "y": [43], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437", "marker": {"color": "#ab63fa"}, "name": "\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437 (16.39% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437", "orientation": "v", "showlegend": true, "text": [40.0], "textposition": "outside", "type": "bar", "x": ["\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0437"], "xaxis": "x", "y": [40], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435", "marker": {"color": "#FFA15A"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (12.70% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435", "orientation": "v", "showlegend": true, "text": [31.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"], "xaxis": "x", "y": [31], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>vacancies=%{text}", "legendgroup": "skill=\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439", "marker": {"color": "#19d3f3"}, "name": "\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0437\u0430\u0434\u0430\u043d\u0438\u0439 (11.07% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u0442\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u043 ...

# %% [markdown]
# # ТОП-15 самых высокооплачиваемых навыков
# Выведем ТОП-15 самых высокооплачиваемых навыков без разделения по вакансиям. При этом будем учитывать только те навыки, по которым есть хотябы 3 вакансии с указанной ЗП для минимальной репрезентативности.

# %%
def find_rows_with_word(word):
  filter_list = []
  for value in df['skills_list']:
    if word in value:
      filter_list.append(True)
    else:
      filter_list.append(False)
  return df[filter_list]

def create_new_columns(row):
  new_data = find_rows_with_word(row['skill'])
  row['vacancies_with_salary'] = new_data.agg({'salary':'count'})[0]
  row['mean_salary'] = new_data.agg({'salary':'mean'})[0]
  row['median_salary'] = new_data.agg({'salary':'median'})[0]
  return row

skills = skills.apply(create_new_columns, axis = 1)
skills_with_max_salary = skills.query('vacancies_with_salary>2 ').sort_values(by='median_salary', ascending=False)
skills_with_max_salary['median_salary'] = (skills_with_max_salary['median_salary']/1000).astype('int')
skills_with_max_salary['text_salary'] = skills_with_max_salary['median_salary'].astype('str') + ' тыс.руб.'

fig = px.bar(skills_with_max_salary.head(15), 
            x='skill', y='median_salary', width = 1300, height = 650, color='skill', 
            text='median_salary')
fig.update_xaxes(tickangle=30)
fig.update_layout(
    title='ТОП-15 самых оплачиваемых навыков в профессиях аналитик / аналитик данных / Data Scientist в СПБ'.format(keyword),
    xaxis_title="Ключевой навык",
    yaxis_title="Средняя заработная плата, тысяч рублей")
fig.update_traces(textposition='inside')
fig.update_yaxes(ticksuffix=" тыс.руб. ")
for trace, percent in zip(fig.data, skills_with_max_salary.head(15)['percent_of_vacancies']):
    trace.name = trace.name.split('=')[1] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1349a070-7cd7-4ea4-9628-cdaa11caad66" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1349a070-7cd7-4ea4-9628-cdaa11caad66")) {
#                     Plotly.newPlot(
#                         '1349a070-7cd7-4ea4-9628-cdaa11caad66',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=Big Data", "marker": {"color": "#636efa"}, "name": "Big Data (3.28% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Big Data", "orientation": "v", "showlegend": true, "text": [120.0], "textposition": "inside", "type": "bar", "x": ["Big Data"], "xaxis": "x", "y": [120], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B2 \u2014 \u0421\u0440\u0435\u0434\u043d\u0435-\u043f\u0440\u043e\u0434\u0432\u0438\u043d\u0443\u0442\u044b\u0439", "marker": {"color": "#EF553B"}, "name": "\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B2 \u2014 \u0421\u0440\u0435\u0434\u043d\u0435-\u043f\u0440\u043e\u0434\u0432\u0438\u043d\u0443\u0442\u044b\u0439 (8.61% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B2 \u2014 \u0421\u0440\u0435\u0434\u043d\u0435-\u043f\u0440\u043e\u0434\u0432\u0438\u043d\u0443\u0442\u044b\u0439", "orientation": "v", "showlegend": true, "text": [115.0], "textposition": "inside", "type": "bar", "x": ["\u0410\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u0438\u0439 \u2014 B2 \u2014 \u0421\u0440\u0435\u0434\u043d\u0435-\u043f\u0440\u043e\u0434\u0432\u0438\u043d\u0443\u0442\u044b\u0439"], "xaxis": "x", "y": [115], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=Linux", "marker": {"color": "#00cc96"}, "name": "Linux (5.74% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=Linux", "orientation": "v", "showlegend": true, "text": [110.0], "textposition": "inside", "type": "bar", "x": ["Linux"], "xaxis": "x", "y": [110], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=SQL", "marker": {"color": "#ab63fa"}, "name": "SQL (26.23% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=SQL", "orientation": "v", "showlegend": true, "text": [100.0], "textposition": "inside", "type": "bar", "x": ["SQL"], "xaxis": "x", "y": [100], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=MS Visio", "marker": {"color": "#FFA15A"}, "name": "MS Visio (8.20% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=MS Visio", "orientation": "v", "showlegend": true, "text": [100.0], "textposition": "inside", "type": "bar", "x": ["MS Visio"], "xaxis": "x", "y": [100], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0437", "marker": {"color": "#19d3f3"}, "name": "\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0437 (7.38% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "skill=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0437", "orientation": "v", "showlegend": true, "text": [100.0], "textposition": "inside", "type": "bar", "x": ["\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0437"], "xaxis": "x", "y": [100], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "skill=%{x}<br>median_salary=%{text}", "legendgroup": "skill=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a\u0430", "marker": {"color": "#FF6692"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a\u04 ...

# %% [markdown]
# # ТОП-15 наиболее частых названий должности аналитика

# %%
df.sort_values(by='salary', ascending=False).head(15)


lists_for_plots = {
    'аналитик':skills_analyst_df,
    'аналитик данных':skills_data_analyst_df,
    'Data Scientist':skills_data_scientist_df, 
    'аналитик / аналитик данных / Data Scientist':skills
}
for column in ['аналитик', 'аналитик данных', 'Data Scientist']:
  most_frequent_job_titles =  pd.DataFrame({'frequency':df.query('keywords==@column')['position'].value_counts()}).reset_index()
  most_frequent_job_titles.columns = ['vacancy', 'frequency']
  most_frequent_job_titles['percent_of_vacancies'] = most_frequent_job_titles['frequency'] / len(df.query('keywords==@column'))
  fig = px.bar(most_frequent_job_titles.head(15), 
              x='vacancy', y='frequency', width = 1300, height = 650, color='vacancy', 
              text='frequency')
  fig.update_xaxes(tickangle=30)
  fig.update_layout(
      title='ТОП-15 наиболее частых названий должности "{}" в СПБ'.format(column),
      xaxis_title="Название вакансии",
      yaxis_title="Частота названия вакансии")
  fig.update_traces(textposition='outside')
  for trace, percent in zip(fig.data, most_frequent_job_titles.head(15)['percent_of_vacancies']):
      trace.name = trace.name.split('=')[1] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'
  fig.show()

most_frequent_job_titles =  pd.DataFrame({'frequency':df['position'].value_counts()}).reset_index()
most_frequent_job_titles.columns = ['vacancy', 'frequency']
most_frequent_job_titles['percent_of_vacancies'] = most_frequent_job_titles['frequency'] / len(df)

fig = px.bar(most_frequent_job_titles.head(15), 
            x='vacancy', y='frequency', width = 1300, height = 650, color='vacancy', 
            text='frequency')
fig.update_xaxes(tickangle=30)
fig.update_layout(
    title='ТОП-15 наиболее частых названий должности "аналитик / аналитик данных / Data Scientist" в СПБ'.format(keyword),
    xaxis_title="Название вакансии",
    yaxis_title="Частота названия вакансии")
fig.update_traces(textposition='outside')
for trace, percent in zip(fig.data, most_frequent_job_titles.head(15)['percent_of_vacancies']):
    trace.name = trace.name.split('=')[1] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6399acd8-c76e-4760-91a5-068bd597a61d" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6399acd8-c76e-4760-91a5-068bd597a61d")) {
#                     Plotly.newPlot(
#                         '6399acd8-c76e-4760-91a5-068bd597a61d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#636efa"}, "name": "\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (5.20% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [17.0], "textposition": "outside", "type": "bar", "x": ["\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [17], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#EF553B"}, "name": "\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (3.98% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [13.0], "textposition": "outside", "type": "bar", "x": ["\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [13], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#00cc96"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a (3.67% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [12.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [12], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#ab63fa"}, "name": "\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (1.22% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [4.0], "textposition": "outside", "type": "bar", "x": ["\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0421\u0442\u0430\u0440\u0448\u0438\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#FFA15A"}, "name": "\u0421\u0442\u0430\u0440\u0448\u0438\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (0.92% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0421\u0442\u0430\u0440\u0448\u0438\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [3.0], "textposition": "outside", "type": "bar", "x": ["\u0421\u0442\u0430\u0440\u0448\u0438\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u04 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="df2ba6f3-4f6c-48db-8104-17c664f5a04f" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("df2ba6f3-4f6c-48db-8104-17c664f5a04f")) {
#                     Plotly.newPlot(
#                         'df2ba6f3-4f6c-48db-8104-17c664f5a04f',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#636efa"}, "name": "\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (8.89% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [28.0], "textposition": "outside", "type": "bar", "x": ["\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [28], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#EF553B"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a (6.67% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [21.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [21], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#00cc96"}, "name": "\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (3.49% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [11.0], "textposition": "outside", "type": "bar", "x": ["\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [11], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#ab63fa"}, "name": "\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (2.54% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [8.0], "textposition": "outside", "type": "bar", "x": ["\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [8], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a BI", "marker": {"color": "#FFA15A"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a BI (1.90% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a BI", "orientation": "v", "showlegend": true, "text": [6.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a BI"], "xaxis": "x", "y": [6], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#19d3f3"}, "name": "\u0424\u0438\u ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e8a44b1f-9e1a-4d0e-a48b-931f9537ff99" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e8a44b1f-9e1a-4d0e-a48b-931f9537ff99")) {
#                     Plotly.newPlot(
#                         'e8a44b1f-9e1a-4d0e-a48b-931f9537ff99',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=Data Scientist", "marker": {"color": "#636efa"}, "name": "Data Scientist (13.51% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=Data Scientist", "orientation": "v", "showlegend": true, "text": [5.0], "textposition": "outside", "type": "bar", "x": ["Data Scientist"], "xaxis": "x", "y": [5], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a-\u043c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u043a (Data scientist)", "marker": {"color": "#EF553B"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a-\u043c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u043a (Data scientist) (5.41% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a-\u043c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u043a (Data scientist)", "orientation": "v", "showlegend": true, "text": [2.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a-\u043c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u043a (Data scientist)"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=Senior Big Data \u0438\u043d\u0436\u0435\u043d\u0435\u0440 (ML)", "marker": {"color": "#00cc96"}, "name": "Senior Big Data \u0438\u043d\u0436\u0435\u043d\u0435\u0440 (ML) (2.70% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=Senior Big Data \u0438\u043d\u0436\u0435\u043d\u0435\u0440 (ML)", "orientation": "v", "showlegend": true, "text": [1.0], "textposition": "outside", "type": "bar", "x": ["Senior Big Data \u0438\u043d\u0436\u0435\u043d\u0435\u0440 (ML)"], "xaxis": "x", "y": [1], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=Market analyst", "marker": {"color": "#ab63fa"}, "name": "Market analyst (2.70% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=Market analyst", "orientation": "v", "showlegend": true, "text": [1.0], "textposition": "outside", "type": "bar", "x": ["Market analyst"], "xaxis": "x", "y": [1], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=Marketing manager", "marker": {"color": "#FFA15A"}, "name": "Marketing manager (2.70% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=Marketing manager", "orientation": "v", "showlegend": true, "text": [1.0], "textposition": "outside", "type": "bar", "x": ["Marketing manager"], "xaxis": "x", "y": [1], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=Senior Data Scientist \u0432 NLP \u043b\u0430\u0431\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u044e \u0421\u041a\u0411 \u041a\u043e\u043d\u0442\u0443\u0440", "marker": {"color": "#19d3f3"}, "name": "Senior Data Scientist \u0432 NLP \u043b\u0430\u0431\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u044e \u0421\u041a\u0411 \u041a\u043e\u043d\u0442\u0443\u0440 (2.70% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=Senior Data Scientist \u0432 NLP \u043b\u0430\u0431\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u044e \u0421\u041a\u0411 \u041a\u043e\u043d\u0442\u0443\u0440", "orientation": "v", "showlegend": true, "text": [1.0], "textposition": "outside", "type": "bar", "x": ["Senior Data Scientist \u0432 NLP \u043b\u0430\u0431\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u044e \u0421\u041a\u0411 \u041a\u043e\u043d\u0442\ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f5fd98df-dc20-4819-a613-0371817f284b" class="plotly-graph-div" style="height:650px; width:1300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5fd98df-dc20-4819-a613-0371817f284b")) {
#                     Plotly.newPlot(
#                         'f5fd98df-dc20-4819-a613-0371817f284b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#636efa"}, "name": "\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (6.63% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [45.0], "textposition": "outside", "type": "bar", "x": ["\u0421\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [45], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#EF553B"}, "name": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a (4.86% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [33.0], "textposition": "outside", "type": "bar", "x": ["\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [33], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#00cc96"}, "name": "\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (3.09% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [21.0], "textposition": "outside", "type": "bar", "x": ["\u0411\u0438\u0437\u043d\u0435\u0441-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [21], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#ab63fa"}, "name": "\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (1.91% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [13.0], "textposition": "outside", "type": "bar", "x": ["\u041c\u0430\u0440\u043a\u0435\u0442\u043e\u043b\u043e\u0433-\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [13], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "vacancy=%{x}<br>frequency=%{text}", "legendgroup": "vacancy=\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "marker": {"color": "#FFA15A"}, "name": "\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a (1.18% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)", "offsetgroup": "vacancy=\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a", "orientation": "v", "showlegend": true, "text": [8.0], "textposition": "outside", "type": "bar", "x": ["\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0439 \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u043a"], "xaxis": "x", "y": [8], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertempl ...

# %% [markdown]
# # Вывод
# На момент проведения анализа рынка (01.05.2020) всего в Санкт-Петербурге по вакансиям аналитика, аналитика данных и Data Scientist было **679** открытых релевантных позиций в **364** компаниях.
#
# Из всего этого числа позиций заработную плату указали только **в 18% случаев**, а ключевые навыки **в 35% случаев**.
#
# > Средние заработные платы находятся на следующем уровне:
# * **`Data Scientist`**: **100000 руб.**
# * **`Аналитик данных`**: **70000 руб.**
# * **`Аналитик`**: **70000 руб.**
#
# > В зависимости от типа вакансии приоритеты ключевых навыков меняются, но можно выделить основные навыки, которые всегда одинаково важны:
# 1. **`SQL`**
# 2. **`Английский язык (принципиальное понимание)`**
# 3. **`Python`**
# 4. **`Бизнес-анализ`**
# 5. **`Статистический анализ`**
#
# > Самыми высокооплачиваемыми навыками, исходя из указанной информации работодателем, в профессии оказались:
# 1. **`Big Data`** - средняя ЗП 120 тыс.руб.
# 2. **`Английский — B2 — Средне-продвинутый`** - средняя ЗП 115 тыс.руб.
# 3. **`Linux`** - средняя ЗП 110 тыс.руб.
# 4. **`SQL`** - средняя ЗП 100 тыс.руб.
# 5. **`Аналитика`** - средняя ЗП 100 тыс.руб.
# 10. При этом **`Python`** стоит на 10-м месте со средней ЗП 90 тыс.руб.
#
# > Наиболее частые названия вакансий должности аналитика:
# 1. **`Системный аналитик`** - 45 раз
# 2. **`Аналитик`** - 23 раз
# 3. **`Бизнес-аналитик`** - 21 - раз
# 4. **`Маркетолог-аналитик`** - 13 раз
# 5. **`Финансовый аналитик`** - 8 раз
# 6. **`Продуктовый аналитик`** - 6 раз
# 7. **`Аналитик BI`** - 6 раз
# 8. **`Data Scientist`** - 5 раз
